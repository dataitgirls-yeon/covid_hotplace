# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import os
import datetime
pd.options.display.max_rows = 20

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

import warnings
warnings.filterwarnings(action='ignore')

## 아래는 matplotlib 한국어 표시해주는 코드

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
food2 = pd.read_excel('음식2.xlsx')

# %%
food1 = pd.read_excel('음식1.xlsx')

# %%
#drop 안에서 axis=1은 column을 지우는 것
org_food2 =food2.drop(['번호', '개방서비스명', '개방서비스ID', '개방자치단체코드', '관리번호', '인허가취소일자',
       '영업상태구분코드',  '상세영업상태코드', '상세영업상태명', '휴업시작일자', '휴업종료일자',
       '재개업일자', '소재지전화', '소재지우편번호', '도로명전체주소', '도로명우편번호',
       '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '좌표정보(X)', '좌표정보(Y)',
       '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총종업원수',
       '본사종업원수', '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액',
       '월세액', '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지'], axis=1)

# %%
org_food1 =food1.drop(['번호', '개방서비스명', '개방서비스ID', '개방자치단체코드', '관리번호', '인허가취소일자',
       '영업상태구분코드',  '상세영업상태코드', '상세영업상태명', '휴업시작일자', '휴업종료일자',
       '재개업일자', '소재지전화', '소재지우편번호', '도로명전체주소', '도로명우편번호',
       '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '좌표정보(X)', '좌표정보(Y)',
       '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총종업원수',
       '본사종업원수', '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액',
       '월세액', '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지'], axis=1)

# %%
org_food2
# Out:
#            인허가일자 영업상태명        폐업일자   소재지면적                     소재지전체주소  업태구분명
# 0       19870721    폐업  20060530.0   18.60       서울특별시 영등포구 신길동 261번지      분식
# 1       19870721    폐업  19950208.0   18.90  서울특별시 영등포구 영등포동5가 129-0번지      한식
# 2       19951011    폐업  19960531.0    2.53    서울특별시 영등포구 대림동 876-13번지      분식
# 3       19951011    폐업  20031210.0  383.03  서울특별시 영등포구 영등포동 618-496번지      분식
# 4       19951012    폐업  20000517.0    6.00   서울특별시 영등포구 영등포동7가 79-1번지      한식
# ...          ...   ...         ...     ...                         ...    ...
# 154570  20010721    폐업  20020507.0   22.50      서울특별시 강동구 상일동 245-0번지      한식
# 154571  20010721    폐업  20040602.0   26.40      서울특별시 강동구 명일동 343-3번지      분식
# 154572  20010721    폐업  20030318.0   87.00      서울특별시 강동구 상일동 458-3번지   호프/통닭
# 154573  20010724    폐업  20050603.0   40.00      서울특별시 강동구 성내동 434-6번지   호프/통닭
# 154574  20010724    폐업  20020603.0   30.00     서울특별시 강동구 천호동 331-21번지      한식
#
# [154575 rows x 6 columns]

# %%
org_food2["폐업일자"] = org_food2["폐업일자"].astype(str)

# %%
org_food1
# Out:
#            인허가일자  영업상태명      폐업일자   소재지면적  \
# 0       20190305  영업/정상       NaN   41.65
# 1       20190305  영업/정상       NaN   60.15
# 2       20190305  영업/정상       NaN  285.05
# 3       20190121  영업/정상       NaN   24.00
# 4       20190123  영업/정상       NaN   77.94
# ...          ...    ...       ...     ...
# 299995  19861127     폐업  19950208   16.65
# 299996  19861128     폐업  19950630   24.94
# 299997  19861201     폐업  20010716   24.35
# 299998  19861202     폐업  20170111  239.62
# 299999  19861203     폐업  19910807   30.70
#
#                                       소재지전체주소            업태구분명
# 0                서울특별시 종로구 수송동 80-6번지 석탄회관빌딩                한식
# 1              서울특별시 종로구 사직동 9번지 광화문 풍림스페이스본                일식
# 2                    서울특별시 종로구 신문로1가 135-2번지   외국음식전문점(인도,태국등)
# 3                      서울특별시 종로구 숭인동 201-7번지              감성주점
# 4                      서울특별시 종로구 사직동 262-4번지               경양식
# ...                                       ...              ...
# ...

# %%
org_food2.head()
# Out:
#       인허가일자 영업상태명        폐업일자   소재지면적                     소재지전체주소 업태구분명
# 0  19870721    폐업  20060530.0   18.60       서울특별시 영등포구 신길동 261번지     분식
# 1  19870721    폐업  19950208.0   18.90  서울특별시 영등포구 영등포동5가 129-0번지     한식
# 2  19951011    폐업  19960531.0    2.53    서울특별시 영등포구 대림동 876-13번지     분식
# 3  19951011    폐업  20031210.0  383.03  서울특별시 영등포구 영등포동 618-496번지     분식
# 4  19951012    폐업  20000517.0    6.00   서울특별시 영등포구 영등포동7가 79-1번지     한식

# %%
#food두개 합치기!!!
real_food = org_food.append(org_food1)

# %%
org_food
# Out:
#            인허가일자 영업상태명        폐업일자   소재지면적                     소재지전체주소  업태구분명
# 0       19870721    폐업  20060530.0   18.60       서울특별시 영등포구 신길동 261번지      분식
# 1       19870721    폐업  19950208.0   18.90  서울특별시 영등포구 영등포동5가 129-0번지      한식
# 2       19951011    폐업  19960531.0    2.53    서울특별시 영등포구 대림동 876-13번지      분식
# 3       19951011    폐업  20031210.0  383.03  서울특별시 영등포구 영등포동 618-496번지      분식
# 4       19951012    폐업  20000517.0    6.00   서울특별시 영등포구 영등포동7가 79-1번지      한식
# ...          ...   ...         ...     ...                         ...    ...
# 154570  20010721    폐업  20020507.0   22.50      서울특별시 강동구 상일동 245-0번지      한식
# 154571  20010721    폐업  20040602.0   26.40      서울특별시 강동구 명일동 343-3번지      분식
# 154572  20010721    폐업  20030318.0   87.00      서울특별시 강동구 상일동 458-3번지   호프/통닭
# 154573  20010724    폐업  20050603.0   40.00      서울특별시 강동구 성내동 434-6번지   호프/통닭
# 154574  20010724    폐업  20020603.0   30.00     서울특별시 강동구 천호동 331-21번지      한식
#
# [154575 rows x 6 columns]

# %%
org_food1
# Out:
#            인허가일자  영업상태명      폐업일자   소재지면적  \
# 0       20190305  영업/정상       NaN   41.65
# 1       20190305  영업/정상       NaN   60.15
# 2       20190305  영업/정상       NaN  285.05
# 3       20190121  영업/정상       NaN   24.00
# 4       20190123  영업/정상       NaN   77.94
# ...          ...    ...       ...     ...
# 299995  19861127     폐업  19950208   16.65
# 299996  19861128     폐업  19950630   24.94
# 299997  19861201     폐업  20010716   24.35
# 299998  19861202     폐업  20170111  239.62
# 299999  19861203     폐업  19910807   30.70
#
#                                       소재지전체주소            업태구분명
# 0                서울특별시 종로구 수송동 80-6번지 석탄회관빌딩                한식
# 1              서울특별시 종로구 사직동 9번지 광화문 풍림스페이스본                일식
# 2                    서울특별시 종로구 신문로1가 135-2번지   외국음식전문점(인도,태국등)
# 3                      서울특별시 종로구 숭인동 201-7번지              감성주점
# 4                      서울특별시 종로구 사직동 262-4번지               경양식
# ...                                       ...              ...
# ...

# %%
real_food.tail(30)
# Out:
#            인허가일자 영업상태명      폐업일자   소재지면적  \
# 299970  19861119    폐업  19890516   62.16
# 299971  19861119    폐업  19910906   29.10
# 299972  19861120    폐업  19940127   26.04
# 299973  19861120    폐업  19921221   37.60
# 299974  19861120    폐업  19970414   75.62
# ...          ...   ...       ...     ...
# 299995  19861127    폐업  19950208   16.65
# 299996  19861128    폐업  19950630   24.94
# 299997  19861201    폐업  20010716   24.35
# 299998  19861202    폐업  20170111  239.62
# 299999  19861203    폐업  19910807   30.70
#
#                                         소재지전체주소 업태구분명     구
# 299970                  서울특별시 영등포구 신길동 234-1번지    경양식  영등포구
# 299971                서울특별시 영등포구 양평동1가 120-2번지     한식  영등포구
# 299972         서울특별시 영등포구 여의도동 44-12번지 고려  1 3호   경양식  영등포구
# 299973       서울특별시 영등포구 여의도동 36-2번지 여의백화점  3 2호    한식  영등포구
# 299974  서울특별시 영등포구 여의도동 43-0번지 미원빌딩    2동  2 5호    한식  영등포구
# ...                                         ...   ...   ...
# ...

# %%
real_food['구'] = real_food['소재지전체주소'].str.split(" ").str[1]

# %%
real_food.head()
# Out:
#       인허가일자 영업상태명         폐업일자   소재지면적                     소재지전체주소 업태구분명     구
# 0  19870721    폐업  2.00605e+07   18.60       서울특별시 영등포구 신길동 261번지     분식  영등포구
# 1  19870721    폐업  1.99502e+07   18.90  서울특별시 영등포구 영등포동5가 129-0번지     한식  영등포구
# 2  19951011    폐업  1.99605e+07    2.53    서울특별시 영등포구 대림동 876-13번지     분식  영등포구
# 3  19951011    폐업  2.00312e+07  383.03  서울특별시 영등포구 영등포동 618-496번지     분식  영등포구
# 4  19951012    폐업  2.00005e+07    6.00   서울특별시 영등포구 영등포동7가 79-1번지     한식  영등포구

# %%
20060500
